# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine, exc
from fuzzywuzzy import process
from datetime import datetime
import argparse
import psycopg2
import re
import pandas as pd
import IPython
from IPython.display import display, HTML

# %%
 db_url = 'postgresql://postgres:root@localhost:5432/PLFS'

# %%
df =  pd.read_excel(f'D:\PLFS\PLFS_Metadata.xlsx', sheet_name='Sheet1' , dtype='str')

# %%
df
# Out:
#                                        indicator_code  \
# 0              Labour Force Participation Rate (LFPR)
# 1                       Worker Population Ratio (WPR)
# 2                              Unemployment Rate (UR)
# 3   Percentage  distribution of usually working pe...
# 4          Percentage distribution of  person working
# 5   Percentage distribution of  person engaged in ...
# 6   Percentage of regular wage/ salaried employees...
# 7   Average wage/salary earnings (Rs. 0.00) during...
# 8   Average no. of days worked in a week for worke...
# 9   Average wage/salary earnings (Rs. 0.00) per da...
# 10  Average gross earnings (Rs. 0.00) during last ...
# 11  average no. of days worked in a week (0.0) for...
# 12  average no. of days actually worked in a week ...
# 13  average number of hours (0.0) actually worked ...
# 14  average no. of hours available for additional ...
# 15  percentage of workers available for additional...
# ...

# %%
columns_df = ['indicator_code', 'status_code','state_code', 'sector_code','age_group_code','gender_code','eduction_level','industry','employment_status',
              'work_industry','broad_employment','enterprise_type','job_contract','quarter','no_days_worked','occupation_divisions','hour_working','sub_industry'
             ,'disaggregation_level','proprietary_partnership','frequency']

# %%
df2 = df[columns_df]

# %%
df2
# Out:
#                                        indicator_code  \
# 0              Labour Force Participation Rate (LFPR)
# 1                       Worker Population Ratio (WPR)
# 2                              Unemployment Rate (UR)
# 3   Percentage  distribution of usually working pe...
# 4          Percentage distribution of  person working
# 5   Percentage distribution of  person engaged in ...
# 6   Percentage of regular wage/ salaried employees...
# 7   Average wage/salary earnings (Rs. 0.00) during...
# 8   Average no. of days worked in a week for worke...
# 9   Average wage/salary earnings (Rs. 0.00) per da...
# 10  Average gross earnings (Rs. 0.00) during last ...
# 11  average no. of days worked in a week (0.0) for...
# 12  average no. of days actually worked in a week ...
# 13  average number of hours (0.0) actually worked ...
# 14  average no. of hours available for additional ...
# 15  percentage of workers available for additional...
# ...

# %%
for key in df2:
    df3 =  df2[key]
    # df3 = df3.str.capitalize()
    df3 = df3.replace("-" , np.nan)
    # df3 = sperator(df3)
    df3 = df3.drop_duplicates()
    df3 = df3.dropna()

    df3 = df3.reset_index(drop = True)
    
    name = ""
    for character in key:
        if character not in ["(" , ")" , "/" , "#"]:
            name+= character
    print(df3)         
    df3.to_excel(f"PLFS_MASTER_EXCEL_SHEETS\{name.split(' ')[0]}.xlsx" , index = False)
    # print(name.split(" ")[0])
    print(f"{key} done")
# Out:
# 0                Labour Force Participation Rate (LFPR)
# 1                         Worker Population Ratio (WPR)
# 2                                Unemployment Rate (UR)
# 3     Percentage  distribution of usually working pe...
# 4            Percentage distribution of  person working
# 5     Percentage distribution of  person engaged in ...
# 6     Percentage of regular wage/ salaried employees...
# 7     Average wage/salary earnings (Rs. 0.00) during...
# 8     Average no. of days worked in a week for worke...
# 9     Average wage/salary earnings (Rs. 0.00) per da...
# 10    Average gross earnings (Rs. 0.00) during last ...
# 11    average no. of days worked in a week (0.0) for...
# 12    average no. of days actually worked in a week ...
# 13    average number of hours (0.0) actually worked ...
# 14    average no. of hours available for additional ...
# 15    percentage of workers available for additional...
# 16    Average wage/salary earnings (Rs.) during the ...
# ...

# %%
# Executing the truncate table indicator
try:
    d_dbCon = psycopg2.connect(user='postgres', password='root', host='localhost', port='5432', database='PLFS')
    curr = d_dbCon.cursor()
    curr.execute('TRUNCATE TABLE  public."indicator" CASCADE')
    d_dbCon.commit()
    curr.close()
    d_dbCon.close()
    print("Table 'indicator' truncated successfully.")

except psycopg2.Error as e:
    print("Error while truncating table:", e)
# Out:
# Table 'indicator' truncated successfully.

# %%
indicatorDf = pd.read_excel(r'C:\Users\T6\PLFS_MASTER_EXCEL_SHEETS\indicator_code.xlsx')
indicatorDf.columns=['indicator_code']
serial = range(1, len(indicatorDf) +1)

indicatorDf2 = pd.DataFrame({
        'indicator_code': serial,
        'indicator_name': indicatorDf['indicator_code'],
        'created_by': 'System',
        'updated_by': 'System',
        'status': "Active"})

engine = create_engine(db_url)
table_name = 'indicator'

indicatorDf2.to_sql(table_name, engine, if_exists='append', index=False)
print(f'indicator table updated')
# Out:
# indicator table updated

# %%
# Executing the truncate table indicator
try:
    d_dbCon = psycopg2.connect(user='postgres', password='root', host='localhost', port='5432', database='PLFS')
    curr = d_dbCon.cursor()
    curr.execute('TRUNCATE TABLE  public."age_group" CASCADE')
    d_dbCon.commit()
    curr.close()
    d_dbCon.close()
    print("Table 'age_group' truncated successfully.")

except psycopg2.Error as e:
    print("Error while truncating table:", e)
# Out:
# Table 'age_group' truncated successfully.

# %%
ageGroupCodeDf = pd.read_excel(r'C:\Users\T6\PLFS_MASTER_EXCEL_SHEETS\age_group_code.xlsx')
ageGroupCodeDf.columns=['age_group_code']
serial = range(1, len(ageGroupCodeDf) +1)

ageGroupCodeDf2 = pd.DataFrame({
        'agegroup_code': serial,
        'agegroup_name': ageGroupCodeDf['age_group_code'],
        'created_by': 'System',
        'updated_by': 'System',
        'status': "Active"})

engine = create_engine(db_url)
table_name = 'age_group'

ageGroupCodeDf2.to_sql(table_name, engine, if_exists='append', index=False)
print(f'age_group table updated')
# Out:
# age_group table updated

# %%
# Executing the truncate table indicator
try:
    d_dbCon = psycopg2.connect(user='postgres', password='root', host='localhost', port='5432', database='PLFS')
    curr = d_dbCon.cursor()
    curr.execute('TRUNCATE TABLE  public."frequency" CASCADE')
    d_dbCon.commit()
    curr.close()
    d_dbCon.close()
    print("Table 'frequency' truncated successfully.")

except psycopg2.Error as e:
    print("Error while truncating table:", e)
# Out:
# Table 'frequency' truncated successfully.

# %%
frequencyDf = pd.read_excel(r'C:\Users\T6\PLFS_MASTER_EXCEL_SHEETS\frequency.xlsx')
frequencyDf.columns=['frequency']
serial = range(1, len(frequencyDf) +1)

frequencyDf2 = pd.DataFrame({
        'frequency_code': serial,
        'frequency_name': frequencyDf['frequency'],
        'created_by': 'System',
        'updated_by': 'System',
        'status': "Active"})

engine = create_engine(db_url)
table_name = 'frequency'

frequencyDf2.to_sql(table_name, engine, if_exists='append', index=False)
print(f'frequency table updated')
# Out:
# indicator table updated

# %%
# Executing the truncate table group
try:
    d_dbCon = psycopg2.connect(user='postgres', password='root', host='localhost', port='5432', database='PLFS')
    curr = d_dbCon.cursor()
    curr.execute('TRUNCATE TABLE  public."group" CASCADE')
    d_dbCon.commit()
    curr.close()
    d_dbCon.close()
    print("Table 'group' truncated successfully.")

except psycopg2.Error as e:
    print("Error while truncating table:", e)
# Out:
# Table 'group' truncated successfully.

# %%
# groupDf = pd.read_excel(r'C:\Users\T6\PLFS_MASTER_EXCEL_SHEETS\group.xlsx')
# groupDf.columns=['group']
# serial = range(1, len(indicatorDf) +1)

# groupDf2 = pd.DataFrame({
#         'group_code': serial,
#         'group_Name': groupDf['group'],
#         'created_by': 'System',
#         'updated_by': 'System',
#         'status': "Active"})

# engine = create_engine(db_url)
# table_name = 'group'

# groupDf2.to_sql(table_name, engine, if_exists='append', index=False)
# print(f'indicator table updated')

# %%
# Executing the truncate table indicator
try:
    d_dbCon = psycopg2.connect(user='postgres', password='root', host='localhost', port='5432', database='PLFS')
    curr = d_dbCon.cursor()
    curr.execute('TRUNCATE TABLE  public."gender" CASCADE')
    d_dbCon.commit()
    curr.close()
    d_dbCon.close()
    print("Table 'gender' truncated successfully.")

except psycopg2.Error as e:
    print("Error while truncating table:", e)
# Out:
# Table 'gender' truncated successfully.

# %%
genderDf = pd.read_excel(r'C:\Users\T6\PLFS_MASTER_EXCEL_SHEETS\gender_code.xlsx')
genderDf.columns=['gender_code']
serial = range(1, len(genderDf) +1)

genderDf2 = pd.DataFrame({
        'gender_code': serial,
        'gender_name': genderDf['gender_code'],
        'created_by': 'System',
        'updated_by': 'System',
        'status': "Active"})

engine = create_engine(db_url)
table_name = 'gender'

genderDf2.to_sql(table_name, engine, if_exists='append', index=False)
print(f'gender table updated')
# Out:
# gender table updated

# %%
# Executing the truncate table indicator
try:
    d_dbCon = psycopg2.connect(user='postgres', password='root', host='localhost', port='5432', database='PLFS')
    curr = d_dbCon.cursor()
    curr.execute('TRUNCATE TABLE  public."sector" CASCADE')
    d_dbCon.commit()
    curr.close()
    d_dbCon.close()
    print("Table 'sector' truncated successfully.")

except psycopg2.Error as e:
    print("Error while truncating table:", e)
# Out:
# Table 'sector' truncated successfully.

# %%
sectorDf = pd.read_excel(r'C:\Users\T6\PLFS_MASTER_EXCEL_SHEETS\sector_code.xlsx')
sectorDf.columns=['sector_code']
serial = range(1, len(sectorDf) +1)

sectorDf2 = pd.DataFrame({
        'sector_code': serial,
        'sector_name': sectorDf['sector_code'],
        'created_by': 'System',
        'updated_by': 'System',
        'status': "Active"})

engine = create_engine(db_url)
table_name = 'sector'

sectorDf2.to_sql(table_name, engine, if_exists='append', index=False)
print(f'sector table updated')
# Out:
# sector table updated

# %%
# Executing the truncate table indicator
try:
    d_dbCon = psycopg2.connect(user='postgres', password='root', host='localhost', port='5432', database='PLFS')
    curr = d_dbCon.cursor()
    curr.execute('TRUNCATE TABLE  public."state" CASCADE')
    d_dbCon.commit()
    curr.close()
    d_dbCon.close()
    print("Table 'state' truncated successfully.")

except psycopg2.Error as e:
    print("Error while truncating table:", e)
# Out:
# Table 'state' truncated successfully.

# %%
stateDf = pd.read_excel(r'C:\Users\T6\PLFS_MASTER_EXCEL_SHEETS\state_code.xlsx')
stateDf.columns=['state_code']
serial = range(1, len(stateDf) +1)

stateDf2 = pd.DataFrame({
        'state_code': serial,
        'state_name': stateDf['state_code'],
        'created_by': 'System',
        'updated_by': 'System',
        'status': "Active"})

engine = create_engine(db_url)
table_name = 'state'

stateDf2.to_sql(table_name, engine, if_exists='append', index=False)
print(f'state table updated')
# Out:
# state table updated

# %%
# Executing the truncate table indicator
try:
    d_dbCon = psycopg2.connect(user='postgres', password='root', host='localhost', port='5432', database='PLFS')
    curr = d_dbCon.cursor()
    curr.execute('TRUNCATE TABLE  public."status_code" CASCADE')
    d_dbCon.commit()
    curr.close()
    d_dbCon.close()
    print("Table 'status_code' truncated successfully.")

except psycopg2.Error as e:
    print("Error while truncating table:", e)
# Out:
# Table 'status_code' truncated successfully.

# %%
statusCodeDf = pd.read_excel(r'C:\Users\T6\PLFS_MASTER_EXCEL_SHEETS\status_code.xlsx')
statusCodeDf.columns=['status_code']
serial = range(1, len(statusCodeDf) +1)

statusCodeDf2 = pd.DataFrame({
        'status_code': serial,
        'status_name': statusCodeDf['status_code'],
        'created_by': 'System',
        'updated_by': 'System',
        'status': "Active"})

engine = create_engine(db_url)
table_name = 'status_code'

statusCodeDf2.to_sql(table_name, engine, if_exists='append', index=False)
print(f'status_code table updated')
# Out:
# status_code table updated

# %%
# Executing the truncate table indicator
try:
    d_dbCon = psycopg2.connect(user='postgres', password='root', host='localhost', port='5432', database='PLFS')
    curr = d_dbCon.cursor()
    curr.execute('TRUNCATE TABLE  public."education_level" CASCADE')
    d_dbCon.commit()
    curr.close()
    d_dbCon.close()
    print("Table 'education_level' truncated successfully.")

except psycopg2.Error as e:
    print("Error while truncating table:", e)
# Out:
# Table 'education_level' truncated successfully.

# %%
educationLevelDf = pd.read_excel(r'C:\Users\T6\PLFS_MASTER_EXCEL_SHEETS\eduction_level.xlsx')
educationLevelDf.columns=['education_level']
serial = range(1, len(educationLevelDf) +1)

educationLevelDf2 = pd.DataFrame({
        'education_level_code': serial,
        'education_level_name': educationLevelDf['education_level'],
        'created_by': 'System',
        'updated_by': 'System',
        'status': "Active"})

engine = create_engine(db_url)
table_name = 'education_level'

educationLevelDf2.to_sql(table_name, engine, if_exists='append', index=False)
print(f'education_level table updated')
# Out:
# education_level table updated

# %%
# Executing the truncate table indicator
try:
    d_dbCon = psycopg2.connect(user='postgres', password='root', host='localhost', port='5432', database='PLFS')
    curr = d_dbCon.cursor()
    curr.execute('TRUNCATE TABLE  public."industry" CASCADE')
    d_dbCon.commit()
    curr.close()
    d_dbCon.close()
    print("Table 'industry' truncated successfully.")

except psycopg2.Error as e:
    print("Error while truncating table:", e)
# Out:
# Table 'industry' truncated successfully.

# %%
industryDf = pd.read_excel(r'C:\Users\T6\PLFS_MASTER_EXCEL_SHEETS\industry.xlsx')
industryDf.columns=['industry']
serial = range(1, len(industryDf) +1)

industryDf2 = pd.DataFrame({
        'industry_code': serial,
        'industry_name': industryDf['industry'],
        'created_by': 'System',
        'updated_by': 'System',
        'status': "Active"})

engine = create_engine(db_url)
table_name = 'industry'

industryDf2.to_sql(table_name, engine, if_exists='append', index=False)
print(f'industry table updated')
# Out:
# industry table updated

# %%
# Executing the truncate table indicator
try:
    d_dbCon = psycopg2.connect(user='postgres', password='root', host='localhost', port='5432', database='PLFS')
    curr = d_dbCon.cursor()
    curr.execute('TRUNCATE TABLE  public."self_employment" CASCADE')
    d_dbCon.commit()
    curr.close()
    d_dbCon.close()
    print("Table 'self_employment' truncated successfully.")

except psycopg2.Error as e:
    print("Error while truncating table:", e)
# Out:
# Table 'self_employment' truncated successfully.

# %%
employmentStatusDf = pd.read_excel(r'C:\Users\T6\PLFS_MASTER_EXCEL_SHEETS\employment_status.xlsx')
employmentStatusDf.columns=['employment_status']
serial = range(1, len(employmentStatusDf) +1)

employmentStatusDf2 = pd.DataFrame({
        'self_employment_code': serial,
        'self_employment_name': employmentStatusDf['employment_status'],
        'created_by': 'System',
        'updated_by': 'System',
        'status': "Active"})

engine = create_engine(db_url)
table_name = 'self_employment'

employmentStatusDf2.to_sql(table_name, engine, if_exists='append', index=False)
print(f'employmentStatus table updated')
# Out:
# employmentStatus table updated

# %%
# Executing the truncate table indicator
try:
    d_dbCon = psycopg2.connect(user='postgres', password='root', host='localhost', port='5432', database='PLFS')
    curr = d_dbCon.cursor()
    curr.execute('TRUNCATE TABLE  public."work_industry" CASCADE')
    d_dbCon.commit()
    curr.close()
    d_dbCon.close()
    print("Table 'work_industry' truncated successfully.")

except psycopg2.Error as e:
    print("Error while truncating table:", e)
# Out:
# Table 'work_industry' truncated successfully.

# %%
workIndustryDf = pd.read_excel(r'C:\Users\T6\PLFS_MASTER_EXCEL_SHEETS\work_industry.xlsx')
workIndustryDf.columns=['work_industry']
serial = range(1, len(workIndustryDf) +1)

workIndustryDf2 = pd.DataFrame({
        'work_industry_code': serial,
        'work_industry_name': workIndustryDf['work_industry'],
        'created_by': 'System',
        'updated_by': 'System',
        'status': "Active"})

engine = create_engine(db_url)
table_name = 'work_industry'

workIndustryDf2.to_sql(table_name, engine, if_exists='append', index=False)
print(f'work_industry table updated')
# Out:
# work_industry table updated

# %%
# Executing the truncate table indicator
try:
    d_dbCon = psycopg2.connect(user='postgres', password='root', host='localhost', port='5432', database='PLFS')
    curr = d_dbCon.cursor()
    curr.execute('TRUNCATE TABLE  public."broad_employment" CASCADE')
    d_dbCon.commit()
    curr.close()
    d_dbCon.close()
    print("Table 'broad_employment' truncated successfully.")

except psycopg2.Error as e:
    print("Error while truncating table:", e)
# Out:
# Table 'broad_employment' truncated successfully.

# %%
broadEmploymentDf = pd.read_excel(r'C:\Users\T6\PLFS_MASTER_EXCEL_SHEETS\broad_employment.xlsx')
broadEmploymentDf.columns=['broad_employment']
serial = range(1, len(broadEmploymentDf) +1)

broadEmploymentDf2 = pd.DataFrame({
        'broad_employment_code': serial,
        'broad_employment_name': broadEmploymentDf['broad_employment'],
        'created_by': 'System',
        'updated_by': 'System',
        'status': "Active"})

engine = create_engine(db_url)
table_name = 'broad_employment'

broadEmploymentDf2.to_sql(table_name, engine, if_exists='append', index=False)
print(f'broad_employment table updated')
# Out:
# broad_employment table updated

# %%
# Executing the truncate table indicator
try:
    d_dbCon = psycopg2.connect(user='postgres', password='root', host='localhost', port='5432', database='PLFS')
    curr = d_dbCon.cursor()
    curr.execute('TRUNCATE TABLE  public."enterprise_type" CASCADE')
    d_dbCon.commit()
    curr.close()
    d_dbCon.close()
    print("Table 'enterprise_type' truncated successfully.")

except psycopg2.Error as e:
    print("Error while truncating table:", e)
# Out:
# Table 'enterprise_type' truncated successfully.

# %%
enterpriseTypeDf = pd.read_excel(r'C:\Users\T6\PLFS_MASTER_EXCEL_SHEETS\enterprise_type.xlsx')
enterpriseTypeDf.columns=['enterprise_type']
serial = range(1, len(enterpriseTypeDf) +1)

enterpriseTypeDf2 = pd.DataFrame({
        'enterprise_type_code': serial,
        'enterprise_type_name': enterpriseTypeDf['enterprise_type'],
        'created_by': 'System',
        'updated_by': 'System',
        'status': "Active"})

engine = create_engine(db_url)
table_name = 'enterprise_type'

enterpriseTypeDf2.to_sql(table_name, engine, if_exists='append', index=False)
print(f'enterprise_type table updated')
# Out:
# enterprise_type table updated

# %%
# Executing the truncate table indicator
try:
    d_dbCon = psycopg2.connect(user='postgres', password='root', host='localhost', port='5432', database='PLFS')
    curr = d_dbCon.cursor()
    curr.execute('TRUNCATE TABLE  public."job_contract" CASCADE')
    d_dbCon.commit()
    curr.close()
    d_dbCon.close()
    print("Table 'job_contract' truncated successfully.")

except psycopg2.Error as e:
    print("Error while truncating table:", e)
# Out:
# Table 'job_contract' truncated successfully.

# %%
jobContractDf = pd.read_excel(r'C:\Users\T6\PLFS_MASTER_EXCEL_SHEETS\job_contract.xlsx')
jobContractDf.columns=['job_contract']
serial = range(1, len(jobContractDf) +1)

jobContractDf2 = pd.DataFrame({
        'job_contract_code': serial,
        'job_contract_name': jobContractDf['job_contract'],
        'created_by': 'System',
        'updated_by': 'System',
        'status': "Active"})

engine = create_engine(db_url)
table_name = 'job_contract'

jobContractDf2.to_sql(table_name, engine, if_exists='append', index=False)
print(f'job_contract table updated')
# Out:
# job_contract table updated

# %%
# Executing the truncate table indicator
try:
    d_dbCon = psycopg2.connect(user='postgres', password='root', host='localhost', port='5432', database='PLFS')
    curr = d_dbCon.cursor()
    curr.execute('TRUNCATE TABLE  public."quarter" CASCADE')
    d_dbCon.commit()
    curr.close()
    d_dbCon.close()
    print("Table 'quarter' truncated successfully.")

except psycopg2.Error as e:
    print("Error while truncating table:", e)
# Out:
# Table 'quarter' truncated successfully.

# %%
quarterDf = pd.read_excel(r'C:\Users\T6\PLFS_MASTER_EXCEL_SHEETS\quarter.xlsx')
quarterDf.columns=['quarter']
serial = range(1, len(quarterDf) +1)

quarterDf2 = pd.DataFrame({
        'quarter_code': serial,
        'quarter_name': quarterDf['quarter'],
        'created_by': 'System',
        'updated_by': 'System',
        'status': "Active"})

engine = create_engine(db_url)
table_name = 'quarter'

quarterDf2.to_sql(table_name, engine, if_exists='append', index=False)
print(f'job_contract table updated')
# Out:
# job_contract table updated

# %%
# Executing the truncate table indicator
try:
    d_dbCon = psycopg2.connect(user='postgres', password='root', host='localhost', port='5432', database='PLFS')
    curr = d_dbCon.cursor()
    curr.execute('TRUNCATE TABLE  public."no_days_worked" CASCADE')
    d_dbCon.commit()
    curr.close()
    d_dbCon.close()
    print("Table 'no_days_worked' truncated successfully.")

except psycopg2.Error as e:
    print("Error while truncating table:", e)
# Out:
# Table 'no_days_worked' truncated successfully.

# %%
noDaysWorkedDf = pd.read_excel(r'C:\Users\T6\PLFS_MASTER_EXCEL_SHEETS\no_days_worked.xlsx')
noDaysWorkedDf.columns=['no_days_worked']
serial = range(1, len(noDaysWorkedDf) +1)

noDaysWorkedDf2 = pd.DataFrame({
        'no_days_worked_code': serial,
        'no_days_worked_name': noDaysWorkedDf['no_days_worked'],
        'created_by': 'System',
        'updated_by': 'System',
        'status': "Active"})

engine = create_engine(db_url)
table_name = 'no_days_worked'

noDaysWorkedDf2.to_sql(table_name, engine, if_exists='append', index=False)
print(f'no_days_worked table updated')
# Out:
# no_days_worked table updated

# %%
# Executing the truncate table indicator
try:
    d_dbCon = psycopg2.connect(user='postgres', password='root', host='localhost', port='5432', database='PLFS')
    curr = d_dbCon.cursor()
    curr.execute('TRUNCATE TABLE  public."occupation_divisions" CASCADE')
    d_dbCon.commit()
    curr.close()
    d_dbCon.close()
    print("Table 'occupation_Divisions' truncated successfully.")

except psycopg2.Error as e:
    print("Error while truncating table:", e)
# Out:
# Table 'occupation_Divisions' truncated successfully.

# %%
occupationDivisionsDf = pd.read_excel(r'C:\Users\T6\PLFS_MASTER_EXCEL_SHEETS\occupation_Divisions.xlsx')
occupationDivisionsDf.columns=['occupation_Divisions']
serial = range(1, len(occupationDivisionsDf) +1)

occupationDivisionsDf2 = pd.DataFrame({
        'occupation_divisions_code': serial,
        'occupation_divisions_name': occupationDivisionsDf['occupation_Divisions'],
        'created_by': 'System',
        'updated_by': 'System'})

engine = create_engine(db_url)
table_name = 'occupation_divisions'

occupationDivisionsDf2.to_sql(table_name, engine, if_exists='append', index=False)
print(f'occupation_divisions table updated')
# Out:
# occupation_divisions table updated

# %%
# Executing the truncate table indicator
try:
    d_dbCon = psycopg2.connect(user='postgres', password='root', host='localhost', port='5432', database='PLFS')
    curr = d_dbCon.cursor()
    curr.execute('TRUNCATE TABLE  public."hour_working" CASCADE')
    d_dbCon.commit()
    curr.close()
    d_dbCon.close()
    print("Table 'hour_working' truncated successfully.")

except psycopg2.Error as e:
    print("Error while truncating table:", e)
# Out:
# Table 'hour_working' truncated successfully.

# %%
hourWorkingsDf = pd.read_excel(r'C:\Users\T6\PLFS_MASTER_EXCEL_SHEETS\hour_working.xlsx')
hourWorkingsDf.columns=['hour_working']
serial = range(1, len(hourWorkingsDf) +1)

hourWorkingsDf2 = pd.DataFrame({
        'hour_working_code': serial,
        'hour_working_name': hourWorkingsDf['hour_working'],
        'created_by': 'System',
        'updated_by': 'System',
        'status': "Active"})

engine = create_engine(db_url)
table_name = 'hour_working'

hourWorkingsDf2.to_sql(table_name, engine, if_exists='append', index=False)
print(f'hour_working table updated')
# Out:
# hour_working table updated

# %%
# Executing the truncate table indicator
try:
    d_dbCon = psycopg2.connect(user='postgres', password='root', host='localhost', port='5432', database='PLFS')
    curr = d_dbCon.cursor()
    curr.execute('TRUNCATE TABLE  public."sub_industry" CASCADE')
    d_dbCon.commit()
    curr.close()
    d_dbCon.close()
    print("Table 'sub_industry' truncated successfully.")

except psycopg2.Error as e:
    print("Error while truncating table:", e)
# Out:
# Table 'sub_industry' truncated successfully.

# %%
subIndustryDf = pd.read_excel(r'C:\Users\T6\PLFS_MASTER_EXCEL_SHEETS\sub_industry.xlsx')
subIndustryDf.columns=['sub_industry']
serial = range(1, len(subIndustryDf) +1)

subIndustryDf2 = pd.DataFrame({
        'sub_industry_code': serial,
        'sub_industry_name': subIndustryDf['sub_industry'],
        'created_by': 'System',
        'updated_by': 'System',
        'status': "Active"})

engine = create_engine(db_url)
table_name = 'sub_industry'

subIndustryDf2.to_sql(table_name, engine, if_exists='append', index=False)
print(f'sub_industry table updated')
# Out:
# sub_industry table updated

# %%
# Executing the truncate table indicator
try:
    d_dbCon = psycopg2.connect(user='postgres', password='root', host='localhost', port='5432', database='PLFS')
    curr = d_dbCon.cursor()
    curr.execute('TRUNCATE TABLE  public."disaggregation_level" CASCADE')
    d_dbCon.commit()
    curr.close()
    d_dbCon.close()
    print("Table 'disaggregation_level' truncated successfully.")

except psycopg2.Error as e:
    print("Error while truncating table:", e)
# Out:
# Table 'disaggregation_level' truncated successfully.

# %%
disaggregationLevelDf = pd.read_excel(r'C:\Users\T6\PLFS_MASTER_EXCEL_SHEETS\disaggregation_level.xlsx')
disaggregationLevelDf.columns=['disaggregation_level']
serial = range(1, len(disaggregationLevelDf) +1)

disaggregationLevelDf2 = pd.DataFrame({
        'disaggregation_level_code': serial,
        'disaggregation_level': disaggregationLevelDf['disaggregation_level'],
        'created_by': 'System',
        'updated_by': 'System',
        'status': "Active"})

engine = create_engine(db_url)
table_name = 'disaggregation_level'

disaggregationLevelDf2.to_sql(table_name, engine, if_exists='append', index=False)
print(f'disaggregation_level table updated')
# Out:
# disaggregation_level table updated

# %%
# Executing the truncate table indicator
try:
    d_dbCon = psycopg2.connect(user='postgres', password='root', host='localhost', port='5432', database='PLFS')
    curr = d_dbCon.cursor()
    curr.execute('TRUNCATE TABLE  public."proprietary_partnership" CASCADE')
    d_dbCon.commit()
    curr.close()
    d_dbCon.close()
    print("Table 'proprietary_partnership' truncated successfully.")

except psycopg2.Error as e:
    print("Error while truncating table:", e)
# Out:
# Table 'proprietary_partnership' truncated successfully.

# %%
proprietaryPartnershipDf = pd.read_excel(r'C:\Users\T6\PLFS_MASTER_EXCEL_SHEETS\proprietary_partnership.xlsx')
proprietaryPartnershipDf.columns=['proprietary_partnership']
serial = range(1, len(proprietaryPartnershipDf) +1)

proprietaryPartnershipDf2 = pd.DataFrame({
        'proprietary_partnership_code': serial,
        'proprietary_partnership_name': proprietaryPartnershipDf['proprietary_partnership'],
        'created_by': 'System',
        'updated_by': 'System',
        'status': "Active"})

engine = create_engine(db_url)
table_name = 'proprietary_partnership'

proprietaryPartnershipDf2.to_sql(table_name, engine, if_exists='append', index=False)
print(f'proprietary_partnership table updated')
# Out:
# proprietary_partnership table updated
